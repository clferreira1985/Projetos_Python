# %% [markdown]
# ## 1. Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##2. Access and Data Processing

# %%
df = pd.read_csv("https://raw.githubusercontent.com/clferreira1985/Datasets/main/HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Shape
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Do we have null values?
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Quantity of Categories per column
df_categorical = df.select_dtypes(include='object')
df_categorical.nunique()
# Out:
# Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# OverTime          2
# dtype: int64

# %%
#Quantity of numerical value per column
df_numerical = df.select_dtypes(exclude='object')
df_numerical.nunique()
# Out:
# Age                           43
# DailyRate                    886
# DistanceFromHome              29
# Education                      5
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobSatisfaction                4
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %%
df_numerical
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
df_categorical
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# I noticed that the dataset has 3 columns with a single value, so I decided to exclude them from the analysis at this point.

# %%
# Drop columns

df = df.drop(["Over18","EmployeeCount", "StandardHours"], axis=1)

# %% [markdown]
# ## 3. Visual representation of the data

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='OverTime', palette = "Blues")

plt.xlabel("Overtime")
plt.ylabel("Count")
plt.title("Count of Satisfaction Levels by Department")

plt.show()

# %%
department_job_satisfaction_counts = df.groupby(['Department', 'JobSatisfaction']).size().unstack()
department_job_satisfaction_counts.columns = ['Satisfação 1', 'Satisfação 2', 'Satisfação 3', 'Satisfação 4']

plt.figure(figsize=(10, 6))
sns.barplot(data=department_job_satisfaction_counts.reset_index(), x="Department", y="Satisfação 1", palette="Blues", label="Satisfação 1")
sns.barplot(data=department_job_satisfaction_counts.reset_index(), x="Department", y="Satisfação 2", palette="Greens", bottom=department_job_satisfaction_counts["Satisfação 1"], label="Satisfação 2")
sns.barplot(data=department_job_satisfaction_counts.reset_index(), x="Department", y="Satisfação 3", palette="Oranges", bottom=department_job_satisfaction_counts["Satisfação 1"] + department_job_satisfaction_counts["Satisfação 2"], label="Satisfação 3")
sns.barplot(data=department_job_satisfaction_counts.reset_index(), x="Department", y="Satisfação 4", palette="Reds", bottom=department_job_satisfaction_counts["Satisfação 1"] + department_job_satisfaction_counts["Satisfação 2"] + department_job_satisfaction_counts["Satisfação 3"], label="Satisfação 4")

plt.xlabel("Department")
plt.ylabel("Count")
plt.title("Count of Satisfaction Levels by Department")

plt.legend(title="Satisfaction Level")
plt.show()

# %% [markdown]
# There is a large number of people who are working beyond regular hours; this is something that is good to investigate if job satisfaction is related to overwork
